# %%
from duckduckgo_search import DDGS

for r in
# Out:
# /var/folders/g1/rglxj_kd46b8lv3l575fqghm0000gn/T/ipykernel_96100/1786832822.py:3: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   for r in DDGS().text("python websearch example", max_results=5):
# Welcome to Python.org - https://www.python.org/
# Python (langage) — Wikipédia - https://fr.wikipedia.org/wiki/Python_(langage)
# Apprenez les bases du langage Python - OpenClassrooms - https://openclassrooms.com/fr/courses/7168871-apprenez-les-bases-du-langage-python
# Cours de Python - u-paris.fr - https://python.sdv.u-paris.fr/cours-python.pdf
# Learn Python - Free Interactive Python Tutorial - https://www.learnpython.org/fr/
